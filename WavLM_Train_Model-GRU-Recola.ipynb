# %% [markdown]
# # Train GRU Model from WavLM features and continuous labels
#
# ### For Recola 2018 Train and Devel dataset

# %% [markdown]
# ##### https://github.com/microsoft/unilm/tree/master/wavlm
# ##### https://github.com/audeering/w2v2-how-to/blob/main/notebook.ipynb

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Process Feature Files - Train and Devel

# %%
# Path to feature files
path_train = 'Recola2018_16k/features/train'
extension = 'wavlmbasefeatpool'

train_files = [file for file in os.listdir(path_train) if file.endswith(extension)]

sorted_train_files = sorted(train_files)
sorted_train_files
# Out:
# ['train_1.wavlmbasefeatpool',
#  'train_2.wavlmbasefeatpool',
#  'train_3.wavlmbasefeatpool',
#  'train_4.wavlmbasefeatpool',
#  'train_5.wavlmbasefeatpool',
#  'train_6.wavlmbasefeatpool',
#  'train_7.wavlmbasefeatpool',
#  'train_8.wavlmbasefeatpool',
#  'train_9.wavlmbasefeatpool']

# %%
# Path to feature files
path_devel = 'Recola2018_16k/features/devel'
extension = 'wavlmbasefeatpool'

devel_files = [file for file in os.listdir(path_devel) if file.endswith(extension)]

sorted_devel_files = sorted(devel_files)
sorted_devel_files
# Out:
# ['dev_1.wavlmbasefeatpool',
#  'dev_2.wavlmbasefeatpool',
#  'dev_3.wavlmbasefeatpool',
#  'dev_4.wavlmbasefeatpool',
#  'dev_5.wavlmbasefeatpool',
#  'dev_6.wavlmbasefeatpool',
#  'dev_7.wavlmbasefeatpool',
#  'dev_8.wavlmbasefeatpool',
#  'dev_9.wavlmbasefeatpool']

# %%
dfs = []
for file in sorted_train_files:
    df = pd.read_csv(os.path.join(path_train, file))
    
    # pad to make single feature files compatible with labels (2 lines for Recola)
    # pad the dataframe with a copy of the first row 
    new_row = pd.DataFrame(df.loc[0])

    # simply concatenate both dataframes
    df = pd.concat([new_row.T, df]).reset_index(drop = True)
    
    # pad the dataframe with a copy of the last row 
    new_row2 = pd.DataFrame(df.loc[len(df)-1])
    
    # simply concatenate both dataframes
    df = pd.concat([df,new_row2.T]).reset_index(drop = True)
    
    dfs.append(df)

df_train_feat = pd.concat(dfs, ignore_index=True)

# Drop first index column (unamed 0)
df_train_feat.drop(df_train_feat.columns[[0]], axis=1, inplace=True)

df_train_feat
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.287043  0.052053 -0.020140 -0.083973 -0.002710 -0.094455 -0.007519
# 1      0.287043  0.052053 -0.020140 -0.083973 -0.002710 -0.094455 -0.007519
# 2      0.280631  0.019296  0.017815 -0.069037  0.012871 -0.100985 -0.062013
# 3      0.260988  0.026328  0.004951 -0.050089  0.034633 -0.091831 -0.089229
# 4      0.189641 -0.038102  0.029187 -0.070187  0.016132 -0.096568 -0.152244
# ...         ...       ...       ...       ...       ...       ...       ...
# 67504 -0.045178 -0.107187 -0.060478 -0.050455  0.103593 -0.024292  0.108691
# 67505 -0.073346  0.025955 -0.132923 -0.077584 -0.009768 -0.083074  0.157465
# 67506 -0.139441  0.021400 -0.115456 -0.085402  0.064270  0.068080 -0.064101
# 67507  0.038998  0.134190 -0.185722  0.006425  0.049627  0.023687  0.110960
# 67508  0.038998  0.134190 -0.185722  0.006425  0.049627  0.023687  0.110960
#
#               7         8         9  ...       758       759       760  \
# 0     -0.009715  0.070949  0.002657  ...  0.036992  0.161464  0.085316
# 1     -0.009715  0.070949  0.002657  ...  0.036992  0.161464  0.085316
# 2     -0.022290  0.163397  0.107826  ... -0.007101  0.155485  0.105061
# 3      0.035907  0.183416  0.153492  ... -0.017694  0.157349  0.090947
# 4      0.066400  0.259290  0.179177  ... -0.046208  0.147277  0.131058
# ...         ...       ...       ...  ...       ...       ...       ...
# 67504 -0.019609  0.062754  0.121068  ...  0.114766 -0.022182 -0.069816
# 67505  0.018694  0.025926 -0.033569  ...  0.022912  0.038415  0.141481
# 67506  0.057752 -0.024166 -0.186699  ... -0.126446  0.007706  0.155883
# 67507 -0.046366 -0.000005 -0.155214  ... -0.158967 -0.133261  0.085344
# 67508 -0.046366 -0.000005 -0.155214  ... -0.158967 -0.133261  0.085344
#
#             761       762       763       764       765       766       767
# 0      1.000897  0.171399 -0.057759  0.070285  0.126770  0.106141  0.604056
# 1      1.000897  0.171399 -0.057759  0.070285  0.126770  0.106141  0.604056
# 2      1.245534  0.198035 -0.073335  0.138528  0.108111  0.125935  0.659750
# 3      1.277041  0.187295 -0.067804  0.121619  0.098807  0.129719  0.632740
# 4      1.139375  0.224708 -0.035480  0.102886  0.097665  0.096764  0.771372
# ...         ...       ...       ...       ...       ...       ...       ...
# 67504  1.633942  0.077471  0.010737  0.006188 -0.053560 -0.038820  0.154500
# 67505  0.543510  0.010589 -0.040598  0.063158 -0.046928 -0.080123  0.323969
# 67506 -0.359285 -0.089562  0.034612  0.043575 -0.095033 -0.040739 -0.449713
# 67507 -0.566554 -0.268961  0.049534  0.080955 -0.120617 -0.139615  1.417126
# 67508 -0.566554 -0.268961  0.049534  0.080955 -0.120617 -0.139615  1.417126
#
# [67509 rows x 768 columns]

# %%
dfs_devel = []
for file in sorted_devel_files:
    df_devel = pd.read_csv(os.path.join(path_devel, file))
    
    # pad to make single feature files compatible with labels (2 lines for Recola)
    # pad the dataframe with a copy of the first row 
    new_row = pd.DataFrame(df_devel.loc[0])

    # simply concatenate both dataframes
    df_devel = pd.concat([new_row.T, df_devel]).reset_index(drop = True)
    
    # pad the dataframe with a copy of the last row 
    new_row2 = pd.DataFrame(df_devel.loc[len(df_devel)-1])
    
    # simply concatenate both dataframes
    df_devel = pd.concat([df_devel,new_row2.T]).reset_index(drop = True)
    
    dfs_devel.append(df_devel)
    
df_devel_feat = pd.concat(dfs_devel, ignore_index=True)

# Drop first index column (unamed 0)
df_devel_feat.drop(df_devel_feat.columns[[0]], axis=1, inplace=True)

df_devel_feat
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.238646  0.084087  0.028877 -0.078474  0.056739 -0.089691 -0.043330
# 1      0.238646  0.084087  0.028877 -0.078474  0.056739 -0.089691 -0.043330
# 2      0.211931  0.098341  0.085483 -0.053753  0.074008 -0.100904 -0.122589
# 3      0.182068  0.094378  0.092790 -0.030379  0.080415 -0.084567 -0.184084
# 4      0.143341  0.090180  0.100481 -0.005192  0.079638 -0.048728 -0.247517
# ...         ...       ...       ...       ...       ...       ...       ...
# 67504  0.027904  0.119710 -0.136735  0.146773 -0.058715  0.039445 -0.056512
# 67505  0.081144  0.111192 -0.125331  0.118674 -0.048430  0.009312 -0.019351
# 67506  0.175888  0.126636 -0.106341  0.131696 -0.035300 -0.013077  0.053262
# 67507  0.131737  0.131993 -0.142118  0.070340 -0.062115  0.045281  0.008546
# 67508  0.131737  0.131993 -0.142118  0.070340 -0.062115  0.045281  0.008546
#
#               7         8         9  ...       758       759       760  \
# 0     -0.089900  0.143496  0.042189  ...  0.024183  0.171355  0.065592
# 1     -0.089900  0.143496  0.042189  ...  0.024183  0.171355  0.065592
# 2     -0.055923  0.208470  0.121186  ... -0.012240  0.181948  0.056408
# 3      0.025038  0.210229  0.144886  ... -0.021612  0.188633  0.042378
# 4      0.050838  0.230621  0.168228  ... -0.060984  0.153103  0.048501
# ...         ...       ...       ...  ...       ...       ...       ...
# 67504  0.097811 -0.004972  0.019265  ... -0.078433  0.168866  0.331171
# 67505  0.108096 -0.021916  0.025030  ... -0.088513  0.188372  0.315841
# 67506  0.116018 -0.030520  0.024510  ... -0.061279  0.164236  0.237918
# 67507 -0.028331 -0.080437 -0.036034  ... -0.095634  0.033959  0.279375
# 67508 -0.028331 -0.080437 -0.036034  ... -0.095634  0.033959  0.279375
#
#             761       762       763       764       765       766       767
# 0      1.195989  0.187410 -0.076942  0.015578  0.144548  0.005386  0.410032
# 1      1.195989  0.187410 -0.076942  0.015578  0.144548  0.005386  0.410032
# 2      1.558745  0.203114 -0.066169  0.058576  0.134333  0.045732  0.441429
# 3      1.630740  0.198598 -0.073841  0.063514  0.116755  0.097646  0.539371
# 4      1.723943  0.192285 -0.062105  0.064657  0.093853  0.082103  0.322427
# ...         ...       ...       ...       ...       ...       ...       ...
# 67504 -0.631903  0.108821  0.003798  0.199048 -0.060948  0.073858 -0.049378
# 67505 -0.553180  0.106020 -0.054775  0.146062 -0.041599  0.074856 -0.050413
# 67506 -0.243618  0.093962 -0.069607  0.073311 -0.036209  0.051816 -0.233181
# 67507 -0.433096  0.063023 -0.052571 -0.034168 -0.029573  0.026302  0.016111
# 67508 -0.433096  0.063023 -0.052571 -0.034168 -0.029573  0.026302  0.016111
#
# [67509 rows x 768 columns]

# %% [markdown]
# ### Process label files - Train and Devel

# %%
# Path to label files
path_train_arousal_labels = 'Recola2018_16k/labels/arousal/Train/'
extension = 'arff'

train_files_arousal_labels = [file for file in os.listdir(path_train_arousal_labels) if file.endswith(extension)]

sorted_train_arousal_labels = sorted(train_files_arousal_labels)
sorted_train_arousal_labels
# Out:
# ['train_1.arff',
#  'train_2.arff',
#  'train_3.arff',
#  'train_4.arff',
#  'train_5.arff',
#  'train_6.arff',
#  'train_7.arff',
#  'train_8.arff',
#  'train_9.arff']

# %%
# Path to label files
path_train_valence_labels = 'Recola2018_16k/labels/valence/Train/'
extension = 'arff'

train_files_valence_labels = [file for file in os.listdir(path_train_valence_labels) if file.endswith(extension)]

sorted_train_valence_labels = sorted(train_files_valence_labels)
sorted_train_valence_labels
# Out:
# ['train_1.arff',
#  'train_2.arff',
#  'train_3.arff',
#  'train_4.arff',
#  'train_5.arff',
#  'train_6.arff',
#  'train_7.arff',
#  'train_8.arff',
#  'train_9.arff']

# %%
# Path to label files
path_devel_arousal_labels = 'Recola2018_16k/labels/arousal/Devel/'
extension = 'arff'

devel_files_arousal_labels = [file for file in os.listdir(path_devel_arousal_labels) if file.endswith(extension)]

sorted_devel_arousal_labels = sorted(devel_files_arousal_labels)
sorted_devel_arousal_labels
# Out:
# ['dev_1.arff',
#  'dev_2.arff',
#  'dev_3.arff',
#  'dev_4.arff',
#  'dev_5.arff',
#  'dev_6.arff',
#  'dev_7.arff',
#  'dev_8.arff',
#  'dev_9.arff']

# %%
# Path to label files
path_devel_valence_labels = 'Recola2018_16k/labels/valence/Devel/'
extension = 'arff'

devel_files_valence_labels = [file for file in os.listdir(path_devel_valence_labels) if file.endswith(extension)]

sorted_devel_valence_labels = sorted(devel_files_valence_labels)
sorted_devel_valence_labels
# Out:
# ['dev_1.arff',
#  'dev_2.arff',
#  'dev_3.arff',
#  'dev_4.arff',
#  'dev_5.arff',
#  'dev_6.arff',
#  'dev_7.arff',
#  'dev_8.arff',
#  'dev_9.arff']

# %%
dfl = []
for file in sorted_train_arousal_labels:
    df2 = pd.read_csv(os.path.join(path_train_arousal_labels, file), sep=",", header=None)
    df2.drop(df2.columns[[0,1]], axis=1, inplace=True)
    dfl.append(df2)

df_train_arousal_lab = pd.concat(dfl, ignore_index=True)
df_train_arousal_lab = df_train_arousal_lab.rename(columns={2:"arousal"})
df_train_arousal_lab
# Out:
#         arousal
# 0     -0.019902
# 1     -0.019902
# 2     -0.019902
# 3     -0.019902
# 4     -0.019902
# ...         ...
# 67504  0.161519
# 67505  0.159852
# 67506  0.156519
# 67507  0.153186
# 67508  0.151519
#
# [67509 rows x 1 columns]

# %%
dfl = []
for file in sorted_train_valence_labels:
    df2 = pd.read_csv(os.path.join(path_train_valence_labels, file), sep=",", header=None)
    df2.drop(df2.columns[[0,1]], axis=1, inplace=True)
    dfl.append(df2)
    
df_train_valence_lab = pd.concat(dfl, ignore_index=True)
df_train_valence_lab = df_train_valence_lab.rename(columns={2:"valence"})
df_train_valence_lab
# Out:
#         valence
# 0     -0.025661
# 1     -0.025661
# 2     -0.025661
# 3     -0.025661
# 4     -0.025661
# ...         ...
# 67504  0.195092
# 67505  0.191759
# 67506  0.191759
# 67507  0.188426
# 67508  0.186759
#
# [67509 rows x 1 columns]

# %%
dfl = []
for file in sorted_devel_arousal_labels:
    df2 = pd.read_csv(os.path.join(path_devel_arousal_labels, file), sep=",", header=None)
    df2.drop(df2.columns[[0,1]], axis=1, inplace=True)
    dfl.append(df2)
    
df_devel_arousal_lab = pd.concat(dfl, ignore_index=True)
df_devel_arousal_lab = df_devel_arousal_lab.rename(columns={2:"arousal"})
df_devel_arousal_lab
# Out:
#         arousal
# 0     -0.022925
# 1     -0.022925
# 2     -0.022925
# 3     -0.022925
# 4     -0.022925
# ...         ...
# 67504 -0.152770
# 67505 -0.149436
# 67506 -0.147770
# 67507 -0.146103
# 67508 -0.142770
#
# [67509 rows x 1 columns]

# %%
dfl = []
for file in sorted_devel_valence_labels:
    df2 = pd.read_csv(os.path.join(path_devel_valence_labels, file), sep=",", header=None)
    df2.drop(df2.columns[[0,1]], axis=1, inplace=True)
    dfl.append(df2)
    
df_devel_valence_lab = pd.concat(dfl, ignore_index=True)
df_devel_valence_lab = df_devel_valence_lab.rename(columns={2:"valence"})
df_devel_valence_lab
# Out:
#         valence
# 0     -0.008826
# 1     -0.008826
# 2     -0.008826
# 3     -0.008826
# 4     -0.008826
# ...         ...
# 67504  0.087291
# 67505  0.088958
# 67506  0.088958
# 67507  0.088958
# 67508  0.088958
#
# [67509 rows x 1 columns]

# %%
df_devel_valence_lab
# Out:
#         valence
# 0     -0.008826
# 1     -0.008826
# 2     -0.008826
# 3     -0.008826
# 4     -0.008826
# ...         ...
# 67504  0.087291
# 67505  0.088958
# 67506  0.088958
# 67507  0.088958
# 67508  0.088958
#
# [67509 rows x 1 columns]

# %% [markdown]
# ## Train a GRU regression model for arousal / valence

# %%
import torch

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
print(torch.cuda.get_device_name(0))
# Out:
# Using device: cuda:1
# NVIDIA RTX A6000

# %%
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True

# %%
def ccc_loss(pred, target):
    mean_pred = torch.mean(pred)
    mean_target = torch.mean(target)

    covar = torch.mean((pred - mean_pred) * (target - mean_target))
    var_pred = torch.var(pred)
    var_target = torch.var(target)

    ccc = 2 * covar / (var_pred + var_target + (mean_pred - mean_target)**2)
    return -ccc  # Minimize -CCC

# Replace the criterion definition in your training loop with:
# criterion = ccc_loss

# %%
import torch.nn as nn
import torch.nn.functional as F

class CCCLoss(nn.Module):
    def __init__(self):
        super(CCCLoss, self).__init__()

    def forward(self, pred, target):
        mean_pred = torch.mean(pred)
        mean_target = torch.mean(target)

        covar = torch.mean((pred - mean_pred) * (target - mean_target))
        var_pred = torch.var(pred)
        var_target = torch.var(target)

        ccc = 2 * covar / (var_pred + var_target + (mean_pred - mean_target)**2)
        return 1 - ccc  # Minimize 1 - CCC

# Example usage:
# criterion = CCCLoss()

# Inside your training loop:
# loss = criterion(predicted_values, target_values)
# print(f'CCC Loss: {loss.item()}')

# %%
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

features = df_train_feat.values.astype(np.float32)
#labels   = df_train_arousal_lab['arousal'].values.astype(np.float32)
labels   = df_train_valence_lab['valence'].values.astype(np.float32)

# Normalize the features between -1 and 1 (adjust scaling based on your data)
# features = (features - np.min(features)) / (np.max(features) - np.min(features)) * 2 - 1

# Convert data to PyTorch tensors
features_tensor = torch.from_numpy(features)
labels_tensor   = torch.from_numpy(labels)

# Assuming you want a sequence length of 1
# features_tensor = features_tensor.unsqueeze(1)

######
# Reshape features tensor with sequence length of 50
sequence_length = 1
num_features    = features.shape[1]
num_samples     = features.shape[0]

# Calculate the number of sequences that can be formed
num_sequences = num_samples // sequence_length

# Truncate the tensor to fit the full sequences
features_tensor = features_tensor[:num_sequences * sequence_length, :]
labels_tensor = labels_tensor[:num_sequences * sequence_length]

# Reshape the tensor
features_tensor = features_tensor.view(num_sequences, sequence_length, num_features)

######

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_tensor, labels_tensor, test_size=0.2, random_state=42)

# Initialize the model, loss function, and optimizer
input_size   = num_features
hidden_size  = 32 #128, 64, 32, 16
num_layers   = 6
output_size  = 1  # Single output for regression between -1 and +1
dropout_prob = 0.10 
# ======================
# Define the GRU model
class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, dropout_prob):
        super(GRUModel, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, dropout_prob, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        gru_out, _ = self.gru(x)
        output = self.fc(gru_out[:, -1, :])  # Take the output from the last time step
        return output

# model = GRUModel(input_size, hidden_size, output_size, dropout_prob)

# =======================
# Define the Convolutional GRU model
class ConvGRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout_prob):
        super(ConvGRUModel, self).__init__()
        self.convgru = nn.GRU(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout=dropout_prob, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        gru_out, _ = self.convgru(x)
        output = self.fc(gru_out[:, -1, :])  # Take the output from the last time step
        return output

model = ConvGRUModel(input_size, hidden_size, num_layers, output_size, dropout_prob)

#=============================
# Define the Convolutional GRU model with Tanh activation at the output
class ConvGRUModelTanh(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout_prob):
        super(ConvGRUModelTanh, self).__init__()
        self.convgru = nn.GRU(input_size=input_size, hidden_size=hidden_size, dropout=dropout_prob, num_layers=num_layers, batch_first=True)
        self.tanh = nn.Tanh()
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        gru_out, _ = self.convgru(x)
        output = self.fc(gru_out[:, -1, :])  # Take the output from the last time step
        output = self.tanh(output)  # Apply Tanh activation
        return output

#model = ConvGRUModelTanh(input_size, hidden_size, num_layers, output_size, dropout_prob)
#=============================

# Move the model to the GPU
model = model.to(device)

#criterion = nn.MSELoss()

#criterion = ccc_loss

criterion = CCCLoss()


optimizer = optim.Adam(model.parameters(), lr=0.001)

# Train the model
num_epochs     = 1000
batch_size     = 7500
validate_every = 2  # Validate every 2 epochs
patience       = 20  # Stop training if validation loss doesn't improve for 5 consecutive validations

train_dataset = TensorDataset(X_train, y_train.unsqueeze(1))
train_loader  = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

# Initialize a list to store the training loss values
train_loss_values = []
validation_loss_values = []

best_validation_loss = float('inf')
early_stop_counter = 0
best_model_path = 'best_model_recola.pth'  # Define the path to save the best model

for epoch in range(num_epochs):
    
    epoch_loss = 0.0
    
    model.train()
    
    for batch_X, batch_y in train_loader:
        optimizer.zero_grad()
        outputs = model(batch_X.to(device))
        loss = criterion(outputs, batch_y.to(device))
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
    
    average_epoch_loss = epoch_loss / len(train_loader)
    train_loss_values.append(average_epoch_loss)
    
    # Validate the model every validate_every epochs using the test partition
    if epoch % validate_every == 0:
        model.eval()
        with torch.no_grad():
            test_outputs = model(X_test.to(device))
            validation_loss = criterion(test_outputs, y_test.unsqueeze(1).to(device))  # Adjust target size

        validation_loss_values.append(validation_loss.item())
        print(f'Epoch [{epoch+1}/{num_epochs}], Validation Loss: {validation_loss.item():.4f}')
        
        if validation_loss < best_validation_loss:
            best_validation_loss = validation_loss
            early_stop_counter = 0
            
            # Save the model with the best validation loss
            torch.save(model.state_dict(), best_model_path)
            print(f'Saved model with best validation loss to {best_model_path}')
        else:
            early_stop_counter += 1

        if early_stop_counter >= patience:
            print(f'Early stopping at epoch {epoch+1} as validation loss has not improved for {patience} consecutive validations.')
            break
            
        model.train()  # Set the model back to training mode
# Out:
# Epoch [1/1000], Loss: 0.9979
# Epoch [1/1000], Validation Loss: 0.9973
# Saved model with best validation loss to best_model_recola.pth
# Epoch [2/1000], Loss: 0.9791
# Epoch [3/1000], Loss: 0.8721
# Epoch [3/1000], Validation Loss: 0.8678
# Saved model with best validation loss to best_model_recola.pth
# Epoch [4/1000], Loss: 0.7697
# Epoch [5/1000], Loss: 0.7160
# Epoch [5/1000], Validation Loss: 0.7400
# Saved model with best validation loss to best_model_recola.pth
# Epoch [6/1000], Loss: 0.6387
# Epoch [7/1000], Loss: 0.5912
# Epoch [7/1000], Validation Loss: 0.6125
# Saved model with best validation loss to best_model_recola.pth
# Epoch [8/1000], Loss: 0.5441
# Epoch [9/1000], Loss: 0.5220
# Epoch [9/1000], Validation Loss: 0.5527
# Saved model with best validation loss to best_model_recola.pth
# Epoch [10/1000], Loss: 0.5167
# Epoch [11/1000], Loss: 0.4859
# Epoch [11/1000], Validation Loss: 0.5110
# Saved model with best validation loss to best_model_recola.pth
# Epoch [12/1000], Loss: 0.4616
# Epoch [13/1000], Loss: 0.4474
# Epoch [13/1000], Validation Loss: 0.4854
# Saved model with best validation loss to best_model_recola.pth
# Epoch [14/1000], Loss: 0.4513
# Epoch [15/1000], Loss: 0.4460
# Epoch [15/1000], Validation Loss: 0.4708
# Saved model with best validation loss to best_model_recola.pth
# Epoch [16/1000], Loss: 0.4231
# Epoch [17/1000], Loss: 0.4257
# Epoch [17/1000], Validation Loss: 0.4601
# Saved model with best validation loss to best_model_recola.pth
# Epoch [18/1000], Loss: 0.4123
# Epoch [19/1000], Loss: 0.4141
# Epoch [19/1000], Validation Loss: 0.4501
# Saved model with best validation loss to best_model_recola.pth
# Epoch [20/1000], Loss: 0.4028
# Epoch [21/1000], Loss: 0.3946
# Epoch [21/1000], Validation Loss: 0.4420
# Saved model with best validation loss to best_model_recola.pth
# Epoch [22/1000], Loss: 0.3835
# Epoch [23/1000], Loss: 0.3855
# Epoch [23/1000], Validation Loss: 0.4330
# Saved model with best validation loss to best_model_recola.pth
# Epoch [24/1000], Loss: 0.3682
# Epoch [25/1000], Loss: 0.3700
# Epoch [25/1000], Validation Loss: 0.4268
# Saved model with best validation loss to best_model_recola.pth
# Epoch [26/1000], Loss: 0.3708
# Epoch [27/1000], Loss: 0.3579
# Epoch [27/1000], Validation Loss: 0.4185
# Saved model with best validation loss to best_model_recola.pth
# Epoch [28/1000], Loss: 0.3609
# Epoch [29/1000], Loss: 0.3538
# Epoch [29/1000], Validation Loss: 0.4114
# Saved model with best validation loss to best_model_recola.pth
# Epoch [30/1000], Loss: 0.3471
# Epoch [31/1000], Loss: 0.3392
# Epoch [31/1000], Validation Loss: 0.4050
# Saved model with best validation loss to best_model_recola.pth
# Epoch [32/1000], Loss: 0.3444
# Epoch [33/1000], Loss: 0.3348
# Epoch [33/1000], Validation Loss: 0.3998
# Saved model with best validation loss to best_model_recola.pth
# Epoch [34/1000], Loss: 0.3388
# Epoch [35/1000], Loss: 0.3211
# Epoch [35/1000], Validation Loss: 0.3944
# Saved model with best validation loss to best_model_recola.pth
# Epoch [36/1000], Loss: 0.3281
# Epoch [37/1000], Loss: 0.3250
# Epoch [37/1000], Validation Loss: 0.3892
# Saved model with best validation loss to best_model_recola.pth
# Epoch [38/1000], Loss: 0.3110
# Epoch [39/1000], Loss: 0.3099
# Epoch [39/1000], Validation Loss: 0.3846
# Saved model with best validation loss to best_model_recola.pth
# Epoch [40/1000], Loss: 0.3073
# Epoch [41/1000], Loss: 0.3050
# Epoch [41/1000], Validation Loss: 0.3804
# Saved model with best validation loss to best_model_recola.pth
# Epoch [42/1000], Loss: 0.3060
# Epoch [43/1000], Loss: 0.2971
# Epoch [43/1000], Validation Loss: 0.3768
# Saved model with best validation loss to best_model_recola.pth
# Epoch [44/1000], Loss: 0.2929
# Epoch [45/1000], Loss: 0.2879
# Epoch [45/1000], Validation Loss: 0.3723
# Saved model with best validation loss to best_model_recola.pth
# Epoch [46/1000], Loss: 0.2769
# Epoch [47/1000], Loss: 0.2746
# Epoch [47/1000], Validation Loss: 0.3693
# Saved model with best validation loss to best_model_recola.pth
# Epoch [48/1000], Loss: 0.2729
# Epoch [49/1000], Loss: 0.2778
# Epoch [49/1000], Validation Loss: 0.3660
# Saved model with best validation loss to best_model_recola.pth
# Epoch [50/1000], Loss: 0.2604
# Epoch [51/1000], Loss: 0.2716
# Epoch [51/1000], Validation Loss: 0.3620
# Saved model with best validation loss to best_model_recola.pth
# Epoch [52/1000], Loss: 0.2705
# Epoch [53/1000], Loss: 0.2619
# Epoch [53/1000], Validation Loss: 0.3593
# Saved model with best validation loss to best_model_recola.pth
# Epoch [54/1000], Loss: 0.2645
# Epoch [55/1000], Loss: 0.2604
# Epoch [55/1000], Validation Loss: 0.3559
# Saved model with best validation loss to best_model_recola.pth
# Epoch [56/1000], Loss: 0.2572
# Epoch [57/1000], Loss: 0.2527
# Epoch [57/1000], Validation Loss: 0.3525
# Saved model with best validation loss to best_model_recola.pth
# Epoch [58/1000], Loss: 0.2534
# Epoch [59/1000], Loss: 0.2541
# Epoch [59/1000], Validation Loss: 0.3497
# Saved model with best validation loss to best_model_recola.pth
# Epoch [60/1000], Loss: 0.2536
# Epoch [61/1000], Loss: 0.2425
# Epoch [61/1000], Validation Loss: 0.3479
# Saved model with best validation loss to best_model_recola.pth
# Epoch [62/1000], Loss: 0.2409
# Epoch [63/1000], Loss: 0.2439
# Epoch [63/1000], Validation Loss: 0.3453
# Saved model with best validation loss to best_model_recola.pth
# Epoch [64/1000], Loss: 0.2352
# Epoch [65/1000], Loss: 0.2440
# Epoch [65/1000], Validation Loss: 0.3432
# Saved model with best validation loss to best_model_recola.pth
# Epoch [66/1000], Loss: 0.2343
# Epoch [67/1000], Loss: 0.2269
# Epoch [67/1000], Validation Loss: 0.3415
# Saved model with best validation loss to best_model_recola.pth
# Epoch [68/1000], Loss: 0.2314
# Epoch [69/1000], Loss: 0.2264
# Epoch [69/1000], Validation Loss: 0.3381
# Saved model with best validation loss to best_model_recola.pth
# Epoch [70/1000], Loss: 0.2299
# Epoch [71/1000], Loss: 0.2242
# Epoch [71/1000], Validation Loss: 0.3363
# Saved model with best validation loss to best_model_recola.pth
# Epoch [72/1000], Loss: 0.2270
# Epoch [73/1000], Loss: 0.2219
# Epoch [73/1000], Validation Loss: 0.3336
# Saved model with best validation loss to best_model_recola.pth
# Epoch [74/1000], Loss: 0.2176
# Epoch [75/1000], Loss: 0.2200
# Epoch [75/1000], Validation Loss: 0.3309
# Saved model with best validation loss to best_model_recola.pth
# Epoch [76/1000], Loss: 0.2211
# Epoch [77/1000], Loss: 0.2167
# Epoch [77/1000], Validation Loss: 0.3285
# Saved model with best validation loss to best_model_recola.pth
# Epoch [78/1000], Loss: 0.2147
# Epoch [79/1000], Loss: 0.2193
# Epoch [79/1000], Validation Loss: 0.3263
# Saved model with best validation loss to best_model_recola.pth
# Epoch [80/1000], Loss: 0.2112
# Epoch [81/1000], Loss: 0.2133
# Epoch [81/1000], Validation Loss: 0.3246
# Saved model with best validation loss to best_model_recola.pth
# Epoch [82/1000], Loss: 0.2079
# Epoch [83/1000], Loss: 0.2057
# Epoch [83/1000], Validation Loss: 0.3220
# Saved model with best validation loss to best_model_recola.pth
# Epoch [84/1000], Loss: 0.2072
# Epoch [85/1000], Loss: 0.2004
# Epoch [85/1000], Validation Loss: 0.3197
# Saved model with best validation loss to best_model_recola.pth
# Epoch [86/1000], Loss: 0.2008
# Epoch [87/1000], Loss: 0.2046
# Epoch [87/1000], Validation Loss: 0.3190
# Saved model with best validation loss to best_model_recola.pth
# Epoch [88/1000], Loss: 0.2002
# Epoch [89/1000], Loss: 0.2022
# Epoch [89/1000], Validation Loss: 0.3178
# Saved model with best validation loss to best_model_recola.pth
# Epoch [90/1000], Loss: 0.1989
# Epoch [91/1000], Loss: 0.1902
# Epoch [91/1000], Validation Loss: 0.3145
# Saved model with best validation loss to best_model_recola.pth
# Epoch [92/1000], Loss: 0.2050
# Epoch [93/1000], Loss: 0.1940
# Epoch [93/1000], Validation Loss: 0.3130
# Saved model with best validation loss to best_model_recola.pth
# Epoch [94/1000], Loss: 0.1950
# Epoch [95/1000], Loss: 0.1905
# Epoch [95/1000], Validation Loss: 0.3119
# Saved model with best validation loss to best_model_recola.pth
# Epoch [96/1000], Loss: 0.1980
# Epoch [97/1000], Loss: 0.1898
# Epoch [97/1000], Validation Loss: 0.3106
# Saved model with best validation loss to best_model_recola.pth
# Epoch [98/1000], Loss: 0.1874
# Epoch [99/1000], Loss: 0.1869
# Epoch [99/1000], Validation Loss: 0.3087
# Saved model with best validation loss to best_model_recola.pth
# Epoch [100/1000], Loss: 0.1941
# Epoch [101/1000], Loss: 0.1857
# Epoch [101/1000], Validation Loss: 0.3069
# Saved model with best validation loss to best_model_recola.pth
# Epoch [102/1000], Loss: 0.1857
# Epoch [103/1000], Loss: 0.1862
# Epoch [103/1000], Validation Loss: 0.3057
# Saved model with best validation loss to best_model_recola.pth
# Epoch [104/1000], Loss: 0.1864
# Epoch [105/1000], Loss: 0.1870
# Epoch [105/1000], Validation Loss: 0.3040
# Saved model with best validation loss to best_model_recola.pth
# Epoch [106/1000], Loss: 0.1784
# Epoch [107/1000], Loss: 0.1777
# Epoch [107/1000], Validation Loss: 0.3035
# Saved model with best validation loss to best_model_recola.pth
# Epoch [108/1000], Loss: 0.1762
# Epoch [109/1000], Loss: 0.1726
# Epoch [109/1000], Validation Loss: 0.3009
# Saved model with best validation loss to best_model_recola.pth
# Epoch [110/1000], Loss: 0.1755
# Epoch [111/1000], Loss: 0.1795
# Epoch [111/1000], Validation Loss: 0.3001
# Saved model with best validation loss to best_model_recola.pth
# Epoch [112/1000], Loss: 0.1778
# Epoch [113/1000], Loss: 0.1738
# Epoch [113/1000], Validation Loss: 0.2989
# Saved model with best validation loss to best_model_recola.pth
# Epoch [114/1000], Loss: 0.1660
# Epoch [115/1000], Loss: 0.1772
# Epoch [115/1000], Validation Loss: 0.2969
# Saved model with best validation loss to best_model_recola.pth
# Epoch [116/1000], Loss: 0.1680
# Epoch [117/1000], Loss: 0.1695
# Epoch [117/1000], Validation Loss: 0.2964
# Saved model with best validation loss to best_model_recola.pth
# Epoch [118/1000], Loss: 0.1735
# Epoch [119/1000], Loss: 0.1659
# Epoch [119/1000], Validation Loss: 0.2965
# Epoch [120/1000], Loss: 0.1692
# Epoch [121/1000], Loss: 0.1627
# Epoch [121/1000], Validation Loss: 0.2945
# Saved model with best validation loss to best_model_recola.pth
# Epoch [122/1000], Loss: 0.1695
# Epoch [123/1000], Loss: 0.1688
# Epoch [123/1000], Validation Loss: 0.2933
# Saved model with best validation loss to best_model_recola.pth
# Epoch [124/1000], Loss: 0.1657
# Epoch [125/1000], Loss: 0.1630
# Epoch [125/1000], Validation Loss: 0.2949
# Epoch [126/1000], Loss: 0.1699
# Epoch [127/1000], Loss: 0.1577
# Epoch [127/1000], Validation Loss: 0.2912
# Saved model with best validation loss to best_model_recola.pth
# Epoch [128/1000], Loss: 0.1595
# Epoch [129/1000], Loss: 0.1632
# Epoch [129/1000], Validation Loss: 0.2900
# Saved model with best validation loss to best_model_recola.pth
# Epoch [130/1000], Loss: 0.1608
# Epoch [131/1000], Loss: 0.1646
# Epoch [131/1000], Validation Loss: 0.2898
# Saved model with best validation loss to best_model_recola.pth
# Epoch [132/1000], Loss: 0.1489
# Epoch [133/1000], Loss: 0.1573
# Epoch [133/1000], Validation Loss: 0.2880
# Saved model with best validation loss to best_model_recola.pth
# Epoch [134/1000], Loss: 0.1621
# Epoch [135/1000], Loss: 0.1564
# Epoch [135/1000], Validation Loss: 0.2865
# Saved model with best validation loss to best_model_recola.pth
# Epoch [136/1000], Loss: 0.1626
# Epoch [137/1000], Loss: 0.1602
# Epoch [137/1000], Validation Loss: 0.2890
# Epoch [138/1000], Loss: 0.1530
# Epoch [139/1000], Loss: 0.1566
# Epoch [139/1000], Validation Loss: 0.2861
# Saved model with best validation loss to best_model_recola.pth
# Epoch [140/1000], Loss: 0.1543
# Epoch [141/1000], Loss: 0.1503
# Epoch [141/1000], Validation Loss: 0.2842
# Saved model with best validation loss to best_model_recola.pth
# Epoch [142/1000], Loss: 0.1485
# Epoch [143/1000], Loss: 0.1575
# Epoch [143/1000], Validation Loss: 0.2828
# Saved model with best validation loss to best_model_recola.pth
# Epoch [144/1000], Loss: 0.1457
# Epoch [145/1000], Loss: 0.1491
# Epoch [145/1000], Validation Loss: 0.2819
# Saved model with best validation loss to best_model_recola.pth
# Epoch [146/1000], Loss: 0.1503
# Epoch [147/1000], Loss: 0.1477
# Epoch [147/1000], Validation Loss: 0.2827
# Epoch [148/1000], Loss: 0.1522
# Epoch [149/1000], Loss: 0.1524
# Epoch [149/1000], Validation Loss: 0.2813
# Saved model with best validation loss to best_model_recola.pth
# Epoch [150/1000], Loss: 0.1532
# Epoch [151/1000], Loss: 0.1453
# Epoch [151/1000], Validation Loss: 0.2793
# Saved model with best validation loss to best_model_recola.pth
# Epoch [152/1000], Loss: 0.1535
# Epoch [153/1000], Loss: 0.1495
# Epoch [153/1000], Validation Loss: 0.2801
# Epoch [154/1000], Loss: 0.1505
# Epoch [155/1000], Loss: 0.1528
# Epoch [155/1000], Validation Loss: 0.2789
# Saved model with best validation loss to best_model_recola.pth
# Epoch [156/1000], Loss: 0.1531
# Epoch [157/1000], Loss: 0.1486
# Epoch [157/1000], Validation Loss: 0.2788
# Saved model with best validation loss to best_model_recola.pth
# Epoch [158/1000], Loss: 0.1442
# Epoch [159/1000], Loss: 0.1346
# Epoch [159/1000], Validation Loss: 0.2767
# Saved model with best validation loss to best_model_recola.pth
# Epoch [160/1000], Loss: 0.1470
# Epoch [161/1000], Loss: 0.1447
# Epoch [161/1000], Validation Loss: 0.2749
# Saved model with best validation loss to best_model_recola.pth
# Epoch [162/1000], Loss: 0.1411
# Epoch [163/1000], Loss: 0.1450
# Epoch [163/1000], Validation Loss: 0.2760
# Epoch [164/1000], Loss: 0.1441
# Epoch [165/1000], Loss: 0.1396
# Epoch [165/1000], Validation Loss: 0.2753
# Epoch [166/1000], Loss: 0.1452
# Epoch [167/1000], Loss: 0.1435
# Epoch [167/1000], Validation Loss: 0.2735
# Saved model with best validation loss to best_model_recola.pth
# Epoch [168/1000], Loss: 0.1383
# Epoch [169/1000], Loss: 0.1392
# Epoch [169/1000], Validation Loss: 0.2747
# Epoch [170/1000], Loss: 0.1362
# Epoch [171/1000], Loss: 0.1413
# Epoch [171/1000], Validation Loss: 0.2751
# Epoch [172/1000], Loss: 0.1369
# Epoch [173/1000], Loss: 0.1379
# Epoch [173/1000], Validation Loss: 0.2721
# Saved model with best validation loss to best_model_recola.pth
# Epoch [174/1000], Loss: 0.1359
# Epoch [175/1000], Loss: 0.1346
# Epoch [175/1000], Validation Loss: 0.2714
# Saved model with best validation loss to best_model_recola.pth
# Epoch [176/1000], Loss: 0.1386
# Epoch [177/1000], Loss: 0.1392
# Epoch [177/1000], Validation Loss: 0.2713
# Saved model with best validation loss to best_model_recola.pth
# Epoch [178/1000], Loss: 0.1380
# Epoch [179/1000], Loss: 0.1295
# Epoch [179/1000], Validation Loss: 0.2686
# Saved model with best validation loss to best_model_recola.pth
# Epoch [180/1000], Loss: 0.1361
# Epoch [181/1000], Loss: 0.1375
# Epoch [181/1000], Validation Loss: 0.2685
# Saved model with best validation loss to best_model_recola.pth
# Epoch [182/1000], Loss: 0.1389
# Epoch [183/1000], Loss: 0.1356
# Epoch [183/1000], Validation Loss: 0.2689
# Epoch [184/1000], Loss: 0.1295
# Epoch [185/1000], Loss: 0.1302
# Epoch [185/1000], Validation Loss: 0.2706
# Epoch [186/1000], Loss: 0.1364
# Epoch [187/1000], Loss: 0.1316
# Epoch [187/1000], Validation Loss: 0.2671
# Saved model with best validation loss to best_model_recola.pth
# Epoch [188/1000], Loss: 0.1289
# Epoch [189/1000], Loss: 0.1281
# Epoch [189/1000], Validation Loss: 0.2690
# Epoch [190/1000], Loss: 0.1297
# Epoch [191/1000], Loss: 0.1238
# Epoch [191/1000], Validation Loss: 0.2694
# Epoch [192/1000], Loss: 0.1278
# Epoch [193/1000], Loss: 0.1329
# Epoch [193/1000], Validation Loss: 0.2663
# Saved model with best validation loss to best_model_recola.pth
# Epoch [194/1000], Loss: 0.1253
# Epoch [195/1000], Loss: 0.1266
# Epoch [195/1000], Validation Loss: 0.2655
# Saved model with best validation loss to best_model_recola.pth
# Epoch [196/1000], Loss: 0.1282
# Epoch [197/1000], Loss: 0.1284
# Epoch [197/1000], Validation Loss: 0.2646
# Saved model with best validation loss to best_model_recola.pth
# Epoch [198/1000], Loss: 0.1281
# Epoch [199/1000], Loss: 0.1240
# Epoch [199/1000], Validation Loss: 0.2658
# Epoch [200/1000], Loss: 0.1240
# Epoch [201/1000], Loss: 0.1247
# Epoch [201/1000], Validation Loss: 0.2649
# Epoch [202/1000], Loss: 0.1265
# Epoch [203/1000], Loss: 0.1267
# Epoch [203/1000], Validation Loss: 0.2632
# Saved model with best validation loss to best_model_recola.pth
# Epoch [204/1000], Loss: 0.1195
# Epoch [205/1000], Loss: 0.1282
# Epoch [205/1000], Validation Loss: 0.2636
# Epoch [206/1000], Loss: 0.1196
# Epoch [207/1000], Loss: 0.1225
# Epoch [207/1000], Validation Loss: 0.2623
# Saved model with best validation loss to best_model_recola.pth
# Epoch [208/1000], Loss: 0.1199
# Epoch [209/1000], Loss: 0.1207
# Epoch [209/1000], Validation Loss: 0.2627
# Epoch [210/1000], Loss: 0.1175
# Epoch [211/1000], Loss: 0.1230
# Epoch [211/1000], Validation Loss: 0.2604
# Saved model with best validation loss to best_model_recola.pth
# Epoch [212/1000], Loss: 0.1239
# Epoch [213/1000], Loss: 0.1193
# Epoch [213/1000], Validation Loss: 0.2594
# Saved model with best validation loss to best_model_recola.pth
# Epoch [214/1000], Loss: 0.1256
# Epoch [215/1000], Loss: 0.1211
# Epoch [215/1000], Validation Loss: 0.2592
# Saved model with best validation loss to best_model_recola.pth
# Epoch [216/1000], Loss: 0.1208
# Epoch [217/1000], Loss: 0.1183
# Epoch [217/1000], Validation Loss: 0.2618
# Epoch [218/1000], Loss: 0.1195
# Epoch [219/1000], Loss: 0.1220
# Epoch [219/1000], Validation Loss: 0.2609
# Epoch [220/1000], Loss: 0.1137
# Epoch [221/1000], Loss: 0.1162
# Epoch [221/1000], Validation Loss: 0.2567
# Saved model with best validation loss to best_model_recola.pth
# Epoch [222/1000], Loss: 0.1212
# Epoch [223/1000], Loss: 0.1164
# Epoch [223/1000], Validation Loss: 0.2573
# Epoch [224/1000], Loss: 0.1218
# Epoch [225/1000], Loss: 0.1190
# Epoch [225/1000], Validation Loss: 0.2571
# Epoch [226/1000], Loss: 0.1126
# Epoch [227/1000], Loss: 0.1177
# Epoch [227/1000], Validation Loss: 0.2562
# Saved model with best validation loss to best_model_recola.pth
# Epoch [228/1000], Loss: 0.1182
# Epoch [229/1000], Loss: 0.1149
# Epoch [229/1000], Validation Loss: 0.2564
# Epoch [230/1000], Loss: 0.1128
# Epoch [231/1000], Loss: 0.1183
# Epoch [231/1000], Validation Loss: 0.2568
# Epoch [232/1000], Loss: 0.1199
# Epoch [233/1000], Loss: 0.1129
# Epoch [233/1000], Validation Loss: 0.2579
# Epoch [234/1000], Loss: 0.1173
# Epoch [235/1000], Loss: 0.1107
# Epoch [235/1000], Validation Loss: 0.2576
# Epoch [236/1000], Loss: 0.1135
# Epoch [237/1000], Loss: 0.1168
# Epoch [237/1000], Validation Loss: 0.2554
# Saved model with best validation loss to best_model_recola.pth
# Epoch [238/1000], Loss: 0.1119
# Epoch [239/1000], Loss: 0.1168
# Epoch [239/1000], Validation Loss: 0.2560
# Epoch [240/1000], Loss: 0.1120
# Epoch [241/1000], Loss: 0.1130
# Epoch [241/1000], Validation Loss: 0.2529
# Saved model with best validation loss to best_model_recola.pth
# Epoch [242/1000], Loss: 0.1141
# Epoch [243/1000], Loss: 0.1097
# Epoch [243/1000], Validation Loss: 0.2538
# Epoch [244/1000], Loss: 0.1086
# Epoch [245/1000], Loss: 0.1067
# Epoch [245/1000], Validation Loss: 0.2528
# Saved model with best validation loss to best_model_recola.pth
# Epoch [246/1000], Loss: 0.1074
# Epoch [247/1000], Loss: 0.1149
# Epoch [247/1000], Validation Loss: 0.2516
# Saved model with best validation loss to best_model_recola.pth
# Epoch [248/1000], Loss: 0.1046
# Epoch [249/1000], Loss: 0.1110
# Epoch [249/1000], Validation Loss: 0.2519
# Epoch [250/1000], Loss: 0.1119
# Epoch [251/1000], Loss: 0.1117
# Epoch [251/1000], Validation Loss: 0.2511
# Saved model with best validation loss to best_model_recola.pth
# Epoch [252/1000], Loss: 0.1069
# Epoch [253/1000], Loss: 0.1075
# Epoch [253/1000], Validation Loss: 0.2520
# Epoch [254/1000], Loss: 0.1075
# Epoch [255/1000], Loss: 0.1094
# Epoch [255/1000], Validation Loss: 0.2499
# Saved model with best validation loss to best_model_recola.pth
# Epoch [256/1000], Loss: 0.1059
# Epoch [257/1000], Loss: 0.1107
# Epoch [257/1000], Validation Loss: 0.2497
# Saved model with best validation loss to best_model_recola.pth
# Epoch [258/1000], Loss: 0.1101
# Epoch [259/1000], Loss: 0.1059
# Epoch [259/1000], Validation Loss: 0.2488
# Saved model with best validation loss to best_model_recola.pth
# Epoch [260/1000], Loss: 0.1064
# Epoch [261/1000], Loss: 0.1076
# Epoch [261/1000], Validation Loss: 0.2495
# Epoch [262/1000], Loss: 0.1078
# Epoch [263/1000], Loss: 0.1100
# Epoch [263/1000], Validation Loss: 0.2496
# Epoch [264/1000], Loss: 0.1115
# Epoch [265/1000], Loss: 0.1081
# Epoch [265/1000], Validation Loss: 0.2489
# Epoch [266/1000], Loss: 0.1063
# Epoch [267/1000], Loss: 0.1078
# Epoch [267/1000], Validation Loss: 0.2503
# Epoch [268/1000], Loss: 0.1102
# Epoch [269/1000], Loss: 0.1082
# Epoch [269/1000], Validation Loss: 0.2490
# Epoch [270/1000], Loss: 0.1027
# Epoch [271/1000], Loss: 0.1042
# Epoch [271/1000], Validation Loss: 0.2477
# Saved model with best validation loss to best_model_recola.pth
# Epoch [272/1000], Loss: 0.1017
# Epoch [273/1000], Loss: 0.0999
# Epoch [273/1000], Validation Loss: 0.2533
# Epoch [274/1000], Loss: 0.1056
# Epoch [275/1000], Loss: 0.1054
# Epoch [275/1000], Validation Loss: 0.2494
# Epoch [276/1000], Loss: 0.1032
# Epoch [277/1000], Loss: 0.0993
# Epoch [277/1000], Validation Loss: 0.2496
# Epoch [278/1000], Loss: 0.1066
# Epoch [279/1000], Loss: 0.0999
# Epoch [279/1000], Validation Loss: 0.2464
# Saved model with best validation loss to best_model_recola.pth
# Epoch [280/1000], Loss: 0.1047
# Epoch [281/1000], Loss: 0.0989
# Epoch [281/1000], Validation Loss: 0.2496
# Epoch [282/1000], Loss: 0.1011
# Epoch [283/1000], Loss: 0.1006
# Epoch [283/1000], Validation Loss: 0.2478
# Epoch [284/1000], Loss: 0.0958
# Epoch [285/1000], Loss: 0.0985
# Epoch [285/1000], Validation Loss: 0.2457
# Saved model with best validation loss to best_model_recola.pth
# Epoch [286/1000], Loss: 0.1007
# Epoch [287/1000], Loss: 0.1022
# Epoch [287/1000], Validation Loss: 0.2450
# Saved model with best validation loss to best_model_recola.pth
# Epoch [288/1000], Loss: 0.1049
# Epoch [289/1000], Loss: 0.0998
# Epoch [289/1000], Validation Loss: 0.2471
# Epoch [290/1000], Loss: 0.1007
# Epoch [291/1000], Loss: 0.0985
# Epoch [291/1000], Validation Loss: 0.2449
# Saved model with best validation loss to best_model_recola.pth
# Epoch [292/1000], Loss: 0.0960
# Epoch [293/1000], Loss: 0.0954
# Epoch [293/1000], Validation Loss: 0.2452
# Epoch [294/1000], Loss: 0.1019
# Epoch [295/1000], Loss: 0.1040
# Epoch [295/1000], Validation Loss: 0.2436
# Saved model with best validation loss to best_model_recola.pth
# Epoch [296/1000], Loss: 0.0948
# Epoch [297/1000], Loss: 0.0999
# Epoch [297/1000], Validation Loss: 0.2436
# Saved model with best validation loss to best_model_recola.pth
# Epoch [298/1000], Loss: 0.0993
# Epoch [299/1000], Loss: 0.0942
# Epoch [299/1000], Validation Loss: 0.2426
# Saved model with best validation loss to best_model_recola.pth
# Epoch [300/1000], Loss: 0.0969
# Epoch [301/1000], Loss: 0.1008
# Epoch [301/1000], Validation Loss: 0.2438
# Epoch [387/1000], Validation Loss: 0.2309
# Saved model with best validation loss to best_model_recola.pth
# Epoch [388/1000], Loss: 0.0880
# Epoch [389/1000], Loss: 0.0801
# Epoch [389/1000], Validation Loss: 0.2303
# Saved model with best validation loss to best_model_recola.pth
# Epoch [390/1000], Loss: 0.0811
# Epoch [391/1000], Loss: 0.0874
# Epoch [391/1000], Validation Loss: 0.2296
# Saved model with best validation loss to best_model_recola.pth
# Epoch [392/1000], Loss: 0.0826
# Epoch [393/1000], Loss: 0.0804
# Epoch [393/1000], Validation Loss: 0.2308
# Epoch [394/1000], Loss: 0.0798
# Epoch [395/1000], Loss: 0.0879
# Epoch [395/1000], Validation Loss: 0.2309
# Epoch [396/1000], Loss: 0.0794
# Epoch [397/1000], Loss: 0.0807
# Epoch [397/1000], Validation Loss: 0.2319
# Epoch [398/1000], Loss: 0.0817
# Epoch [399/1000], Loss: 0.0855
# Epoch [399/1000], Validation Loss: 0.2309
# Epoch [400/1000], Loss: 0.0754
# Epoch [401/1000], Loss: 0.0843
# Epoch [401/1000], Validation Loss: 0.2320
# Epoch [402/1000], Loss: 0.0820
# Epoch [403/1000], Loss: 0.0788
# Epoch [403/1000], Validation Loss: 0.2300
# Epoch [404/1000], Loss: 0.0871
# Epoch [405/1000], Loss: 0.0799
# Epoch [405/1000], Validation Loss: 0.2299
# Epoch [406/1000], Loss: 0.0800
# Epoch [407/1000], Loss: 0.0811
# Epoch [407/1000], Validation Loss: 0.2277
# Saved model with best validation loss to best_model_recola.pth
# Epoch [408/1000], Loss: 0.0792
# Epoch [409/1000], Loss: 0.0823
# Epoch [409/1000], Validation Loss: 0.2306
# Epoch [410/1000], Loss: 0.0799
# Epoch [411/1000], Loss: 0.0783
# Epoch [411/1000], Validation Loss: 0.2304
# Epoch [412/1000], Loss: 0.0848
# Epoch [413/1000], Loss: 0.0762
# Epoch [413/1000], Validation Loss: 0.2276
# Saved model with best validation loss to best_model_recola.pth
# Epoch [414/1000], Loss: 0.0812
# Epoch [415/1000], Loss: 0.0806
# Epoch [415/1000], Validation Loss: 0.2275
# Saved model with best validation loss to best_model_recola.pth
# Epoch [416/1000], Loss: 0.0766
# Epoch [417/1000], Loss: 0.0788
# Epoch [417/1000], Validation Loss: 0.2310
# Epoch [418/1000], Loss: 0.0788
# Epoch [419/1000], Loss: 0.0820
# Epoch [419/1000], Validation Loss: 0.2301
# Epoch [420/1000], Loss: 0.0838
# Epoch [421/1000], Loss: 0.0785
# Epoch [421/1000], Validation Loss: 0.2276
# Epoch [422/1000], Loss: 0.0738
# Epoch [423/1000], Loss: 0.0776
# Epoch [423/1000], Validation Loss: 0.2274
# Saved model with best validation loss to best_model_recola.pth
# Epoch [424/1000], Loss: 0.0771
# Epoch [425/1000], Loss: 0.0807
# Epoch [425/1000], Validation Loss: 0.2260
# Saved model with best validation loss to best_model_recola.pth
# Epoch [426/1000], Loss: 0.0770
# Epoch [427/1000], Loss: 0.0838
# Epoch [427/1000], Validation Loss: 0.2286
# Epoch [428/1000], Loss: 0.0805
# Epoch [694/1000], Loss: 0.0579
# Epoch [695/1000], Loss: 0.0628
# Epoch [695/1000], Validation Loss: 0.2117
# Epoch [696/1000], Loss: 0.0613
# Epoch [697/1000], Loss: 0.0582
# Epoch [697/1000], Validation Loss: 0.2116
# Epoch [698/1000], Loss: 0.0613
# Epoch [699/1000], Loss: 0.0575
# Epoch [699/1000], Validation Loss: 0.2136
# Epoch [700/1000], Loss: 0.0582
# Epoch [701/1000], Loss: 0.0575
# Epoch [701/1000], Validation Loss: 0.2115
# Saved model with best validation loss to best_model_recola.pth
# Epoch [702/1000], Loss: 0.0611
# Epoch [703/1000], Loss: 0.0605
# Epoch [703/1000], Validation Loss: 0.2108
# Saved model with best validation loss to best_model_recola.pth
# Epoch [704/1000], Loss: 0.0542
# Epoch [705/1000], Loss: 0.0562
# Epoch [705/1000], Validation Loss: 0.2116
# Epoch [706/1000], Loss: 0.0528
# Epoch [707/1000], Loss: 0.0592
# Epoch [707/1000], Validation Loss: 0.2121
# Epoch [708/1000], Loss: 0.0578
# Epoch [709/1000], Loss: 0.0587
# Epoch [709/1000], Validation Loss: 0.2106
# Saved model with best validation loss to best_model_recola.pth
# Epoch [710/1000], Loss: 0.0567
# Epoch [711/1000], Loss: 0.0552
# Epoch [711/1000], Validation Loss: 0.2103
# Saved model with best validation loss to best_model_recola.pth
# Epoch [712/1000], Loss: 0.0527
# Epoch [713/1000], Loss: 0.0610
# Epoch [713/1000], Validation Loss: 0.2124
# Epoch [714/1000], Loss: 0.0588
# Epoch [715/1000], Loss: 0.0535
# Epoch [715/1000], Validation Loss: 0.2117
# Epoch [716/1000], Loss: 0.0561
# Epoch [717/1000], Loss: 0.0609
# Epoch [717/1000], Validation Loss: 0.2132
# Epoch [718/1000], Loss: 0.0559
# Epoch [719/1000], Loss: 0.0548
# Epoch [719/1000], Validation Loss: 0.2096
# Saved model with best validation loss to best_model_recola.pth
# Epoch [720/1000], Loss: 0.0533
# Epoch [721/1000], Loss: 0.0566
# Epoch [721/1000], Validation Loss: 0.2127
# Epoch [722/1000], Loss: 0.0590
# Epoch [723/1000], Loss: 0.0557
# Epoch [723/1000], Validation Loss: 0.2113
# Epoch [724/1000], Loss: 0.0599
# Epoch [725/1000], Loss: 0.0538
# Epoch [725/1000], Validation Loss: 0.2135
# Epoch [726/1000], Loss: 0.0586
# Epoch [727/1000], Loss: 0.0535
# Epoch [727/1000], Validation Loss: 0.2119
# Epoch [728/1000], Loss: 0.0603
# Epoch [729/1000], Loss: 0.0549
# Epoch [729/1000], Validation Loss: 0.2137
# Epoch [730/1000], Loss: 0.0566
# Epoch [731/1000], Loss: 0.0575
# Epoch [731/1000], Validation Loss: 0.2120
# Epoch [732/1000], Loss: 0.0598
# Epoch [733/1000], Loss: 0.0540
# Epoch [733/1000], Validation Loss: 0.2106
# Epoch [734/1000], Loss: 0.0592
# Epoch [735/1000], Loss: 0.0566
# Epoch [735/1000], Validation Loss: 0.2116
# Epoch [736/1000], Loss: 0.0586
# Epoch [737/1000], Loss: 0.0549
# Epoch [737/1000], Validation Loss: 0.2123
# Epoch [738/1000], Loss: 0.0587
# Epoch [739/1000], Loss: 0.0516
# Epoch [739/1000], Validation Loss: 0.2129
# Epoch [740/1000], Loss: 0.0561
# Epoch [741/1000], Loss: 0.0556
# Epoch [741/1000], Validation Loss: 0.2136
# Epoch [742/1000], Loss: 0.0595
# Epoch [743/1000], Loss: 0.0550
# Epoch [743/1000], Validation Loss: 0.2118
# Epoch [744/1000], Loss: 0.0566
# Epoch [745/1000], Loss: 0.0575
# Epoch [745/1000], Validation Loss: 0.2116
# Epoch [746/1000], Loss: 0.0575
# Epoch [747/1000], Loss: 0.0594
# Epoch [747/1000], Validation Loss: 0.2126
# Epoch [748/1000], Loss: 0.0573
# Epoch [749/1000], Loss: 0.0550
# Epoch [749/1000], Validation Loss: 0.2126
# Epoch [750/1000], Loss: 0.0586
# Epoch [751/1000], Loss: 0.0560
# Epoch [751/1000], Validation Loss: 0.2115
# Epoch [752/1000], Loss: 0.0561
# Epoch [753/1000], Loss: 0.0565
# Epoch [753/1000], Validation Loss: 0.2114
# Epoch [754/1000], Loss: 0.0547
# Epoch [755/1000], Loss: 0.0562
# Epoch [755/1000], Validation Loss: 0.2110
# Epoch [756/1000], Loss: 0.0559
# Epoch [757/1000], Loss: 0.0605
# Epoch [757/1000], Validation Loss: 0.2133
# Epoch [758/1000], Loss: 0.0537
# Epoch [759/1000], Loss: 0.0591
# Epoch [759/1000], Validation Loss: 0.2135
# Early stopping at epoch 759 as validation loss has not improved for 20 consecutive validations.

# %%
# Test the model
# Load the best model for testing
best_model = ConvGRUModel(input_size, hidden_size, num_layers, output_size, dropout_prob)
best_model.load_state_dict(torch.load(best_model_path))
best_model.to(device)

best_model.eval()
with torch.no_grad():
    test_outputs = best_model(X_test.to(device))
    test_loss    = criterion(test_outputs, y_test.unsqueeze(1).to(device))

print(f'Test Loss: {test_loss.item():.4f}')
# Out:
# Test Loss: 0.2096

# %% [raw]
# # Define the Convolutional BLSTM model with dropout
# class ConvBLSTMModel(nn.Module):
#     def __init__(self, input_size, hidden_size, num_layers, output_size, dropout_prob=0.2):
#         super(ConvBLSTMModel, self).__init__()
#         self.convblstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers,
#                                  batch_first=True, bidirectional=True, dropout=dropout_prob)
#         self.dropout = nn.Dropout(p=dropout_prob)
#         self.fc = nn.Linear(hidden_size * 2, output_size)  # Multiply by 2 for bidirectional
#
#     def forward(self, x):
#         blstm_out, _ = self.convblstm(x)
#         output = self.dropout(blstm_out[:, -1, :])  # Apply dropout before the fully connected layer
#         output = self.fc(output)  # Take the output from the last time step
#         return output
#
# # Initialize the model, loss function, and optimizer
# input_size = num_features
# hidden_size = 128
# num_layers = 4
# output_size = 1  # Single output for regression between -1 and +1
# dropout_prob = 0.2  # Dropout probability
#
# model = ConvBLSTMModel(input_size, hidden_size, num_layers, output_size, dropout_prob)
# criterion = nn.MSELoss()
# optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
features.shape, labels.shape
# Out:
# ((67509, 768), (67509,))

# %%
import matplotlib.pyplot as plt
# Plot the training loss values
plt.plot(train_loss_values, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
plt.show()

# %%
# Plot the training and validation loss values
epochs = range(1, len(train_loss_values) + 1)
plt.plot(epochs, train_loss_values, label='Training Loss')
plt.plot(range(0, len(validation_loss_values) * validate_every, validate_every), validation_loss_values, label='Validation Loss', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.show()

# %%
features2 = df_devel_feat.values.astype(np.float32)
#labels2   = df_devel_arousal_lab['arousal'].values.astype(np.float32)
labels2   = df_devel_valence_lab['valence'].values.astype(np.float32)

# Normalize the features between -1 and 1 (adjust scaling based on your data)
# features2 = (features - np.min(features)) / (np.max(features) - np.min(features)) * 2 - 1

# Convert data to PyTorch tensors
features_tensor2 = torch.from_numpy(features2)
labels_tensor2   = torch.from_numpy(labels2)

######
# Reshape features tensor with sequence length of 50
sequence_length = 1
num_features = features2.shape[1]
num_samples  = features2.shape[0]

# Calculate the number of sequences that can be formed
num_sequences = num_samples // sequence_length

# Truncate the tensor to fit the full sequences
features_tensor2 = features_tensor2[:num_sequences * sequence_length, :]
labels_tensor2   = labels_tensor2[:num_sequences * sequence_length]

# Reshape the tensor
features_tensor2 = features_tensor2.view(num_sequences, sequence_length, num_features)
######

# %%
features_tensor2.size()
# Out:
# torch.Size([67509, 1, 768])

# %%
# Load the best model for testing
best_model = ConvGRUModel(input_size, hidden_size, num_layers, output_size, dropout_prob)
best_model.load_state_dict(torch.load(best_model_path))
best_model.to(device)

with torch.no_grad():
    test_outputs = best_model(features_tensor2.to(device))
    test_loss    = criterion(test_outputs, labels_tensor2.unsqueeze(1).to(device))

print(f'Test Loss: {test_loss.item():.4f}')
# Out:
# Test Loss: 0.7761

# %%
test_outputs
# Out:
# tensor([[-0.0211],
#         [-0.0186],
#         [-0.0645],
#         ...,
#         [ 0.0257],
#         [ 0.1046],
#         [ 0.0275]], device='cuda:1')

# %% [markdown]
# ### Arousal

# %% [markdown]
# #### Smooth function to smooth predictions

# %%
from pandas import DataFrame
from pandas import concat

def F_Smooth(prediction, win_width):

    df_pred = pd.DataFrame(prediction)
    width = win_width
    lag1 = df_pred.shift(1)
    lag3 = df_pred.shift(width - 1)
    window = lag3.rolling(window=width)
    means = window.mean()
    df_smoothed = concat([means, lag1, df_pred], axis=1)
    df_smoothed.columns = ['mean', 't-1', 't+1']
    df_smoothed['mean'] = df_smoothed['mean'].fillna(df_smoothed['t+1'])
    
    return df_smoothed['mean']

# %% [markdown]
# #### Predict on Devel set

# %%
predict_y_devel_arousal = test_outputs.cpu().squeeze(1)

# %%
predict_y_devel_arousal.shape
# Out:
# torch.Size([67509])

# %%
import audmetric

print("CCC = " + str(audmetric.concordance_cc(df_devel_arousal_lab['arousal'], predict_y_devel_arousal)))
print("MSE = " + str(audmetric.mean_absolute_error(df_devel_arousal_lab['arousal'], predict_y_devel_arousal)))
print("MAE = " + str(audmetric.mean_squared_error(df_devel_arousal_lab['arousal'], predict_y_devel_arousal)))
# Out:
# CCC = 0.18286689771181086
# MSE = 0.18947473243891472
# MAE = 0.05643411023511892

# %%
print("CCC = " + str(audmetric.concordance_cc(df_devel_arousal_lab['arousal'], F_Smooth(predict_y_devel_arousal, 5))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_arousal_lab['arousal'], F_Smooth(predict_y_devel_arousal, 10))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_arousal_lab['arousal'], F_Smooth(predict_y_devel_arousal, 15))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_arousal_lab['arousal'], F_Smooth(predict_y_devel_arousal, 20))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_arousal_lab['arousal'], F_Smooth(predict_y_devel_arousal, 25))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_arousal_lab['arousal'], F_Smooth(predict_y_devel_arousal, 30))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_arousal_lab['arousal'], F_Smooth(predict_y_devel_arousal, 35))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_arousal_lab['arousal'], F_Smooth(predict_y_devel_arousal, 40))))

print("MSE = " + str(audmetric.mean_absolute_error(df_devel_arousal_lab['arousal'], F_Smooth(predict_y_devel_arousal, 20))))
print("MAE = " + str(audmetric.mean_squared_error(df_devel_arousal_lab['arousal'], F_Smooth(predict_y_devel_arousal, 20))))
# Out:
# CCC = 0.19119326424153107
# CCC = 0.19144126100368045
# CCC = 0.18951833265124446
# CCC = 0.18738733489413004
# CCC = 0.18530743200040609
# CCC = 0.18318142409256818
# CCC = 0.18094830950798366
# CCC = 0.17869051617567797
# MSE = 0.18039357093274652
# MAE = 0.05218994081558676

# %% [raw]
# ##### Best results so far Arousal Devel:
#
# CCC = 0.6502180381381223
# MSE = 0.12180417567966605
# MAE = 0.023552493286225967
#
# Smooth 20
# CCC = 0.7240553005896032
# MSE = 0.10486073252579436
# MAE = 0.017046109927759553
#
# input_size   = num_features
# hidden_size  = 32 #128, 64, 32, 16
# num_layers   = 6
# output_size  = 1  # Single output for regression between -1 and +1
# dropout_prob = 0.20
#
# num_epochs     = 500
# batch_size     = 7500
# validate_every = 2  # Validate every 2 epochs
# patience       = 20
# dropout_prob   = 0

# %% [markdown]
# ### Valence

# %%
predict_y_devel_valence = test_outputs.cpu().squeeze(1)

# %%
predict_y_devel_valence.shape
# Out:
# torch.Size([67509])

# %%
import audmetric

print("CCC = " + str(audmetric.concordance_cc(df_devel_valence_lab['valence'], predict_y_devel_valence)))
print("MSE = " + str(audmetric.mean_absolute_error(df_devel_valence_lab['valence'], predict_y_devel_valence)))
print("MAE = " + str(audmetric.mean_squared_error(df_devel_valence_lab['valence'], predict_y_devel_valence)))
# Out:
# CCC = 0.2239142572850736
# MSE = 0.11414890271135636
# MAE = 0.022287523223698737

# %%
print("CCC = " + str(audmetric.concordance_cc(df_devel_valence_lab['valence'], F_Smooth(predict_y_devel_valence, 5))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_valence_lab['valence'], F_Smooth(predict_y_devel_valence, 10))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_valence_lab['valence'], F_Smooth(predict_y_devel_valence, 15))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_valence_lab['valence'], F_Smooth(predict_y_devel_valence, 20))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_valence_lab['valence'], F_Smooth(predict_y_devel_valence, 25))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_valence_lab['valence'], F_Smooth(predict_y_devel_valence, 30))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_valence_lab['valence'], F_Smooth(predict_y_devel_valence, 35))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_valence_lab['valence'], F_Smooth(predict_y_devel_valence, 40))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_valence_lab['valence'], F_Smooth(predict_y_devel_valence, 45))))
print("CCC = " + str(audmetric.concordance_cc(df_devel_valence_lab['valence'], F_Smooth(predict_y_devel_valence, 50))))

print("MSE = " + str(audmetric.mean_absolute_error(df_devel_valence_lab['valence'], F_Smooth(predict_y_devel_valence, 25))))
print("MAE = " + str(audmetric.mean_squared_error(df_devel_valence_lab['valence'], F_Smooth(predict_y_devel_valence, 25))))
# Out:
# CCC = 0.25711940693631524
# CCC = 0.26994255714355025
# CCC = 0.27609254984468995
# CCC = 0.2783404669990334
# CCC = 0.27851153757735
# CCC = 0.27718868017818554
# CCC = 0.2750001823712947
# CCC = 0.27226768476661645
# CCC = 0.26889282440507545
# CCC = 0.26516259156723637
# MSE = 0.10050071004249621
# MAE = 0.017071718458134866

# %% [raw]
# ##### Best results so far Valence Devel:
#
# CCC = 0.24962586338410833
# MSE = 0.11577044234488856
# MAE = 0.022763478260014066
#
# Smooth 25
# CCC = 0.30717355249244577
# MSE = 0.1018100746465588
# MAE = 0.01726629305123923
#
# input_size   = num_features
# hidden_size  = 64 #128, 64, 32, 16
# num_layers   = 8
# output_size  = 1  # Single output for regression between -1 and +1
# dropout_prob = 0.20
# CCC_loss
#
# num_epochs     = 500
# batch_size     = 7500
# validate_every = 2  # Validate every 2 epochs
# patience       = 20
# dropout_prob   = 0

# %%
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)
predict_y = F_Smooth(predict_y_devel_arousal, 5)

dt = 1
t = np.arange(0, len(predict_y), dt)
s1 = df_devel_arousal_lab['arousal']
s2 = predict_y                # white noise 2

fig, axs = plt.subplots(2, 1)
axs[0].plot(t, s1, t, s2)
axs[0].set_xlim(0, len(predict_y))
axs[0].set_xlabel('time')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
axs[1].set_ylabel('coherence')

fig.tight_layout()
plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

plt.figure(figsize=(200,6))
#fig.tight_layout()

predict_y = F_Smooth(predict_y_devel_valence, 20)

dt = 1
t = np.arange(0, len(predict_y), dt)
s1 = df_devel_valence_lab['valence']
s2 = predict_y               # white noise 2

fig, axs = plt.subplots(2, 1)
axs[0].plot(t, s2, t, s1)
axs[0].set_xlim(0, len(predict_y))
axs[0].set_xlabel('time')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
axs[1].set_ylabel('coherence')

#plt.figure(figsize=(20,6))
#fig.tight_layout()
plt.show()
